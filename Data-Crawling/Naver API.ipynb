# %% [markdown]
# ## 네이버 검색 API 서비스
#
# ### 네이버 웹문서 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

# naver application clientID,secret
client_id = "6E6mBjvxbdEgVk6Prqgd"
client_secret = "0ZjWnYiBjr"


# quote가 인코딩을 변경(UTF8로 url에 넘겨주기 위해서)
# 내가 입력한 값을 기준으로 parse
query = urllib.parse.quote(input("검색 질의: "))
idx = 0 # 요청 개수
display = 100 # 100개 단위로 가져온다
start = 1
end = 100

# 데이터 프레임 생성
web_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
    # json 결과
    url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    # request 요청에 대한 결과를 response에 저장
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '',items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1
            
    else:
        print("Error Code:" + rescode)

web_df
# Out:
# 검색 질의:  명주 하녹
#                                                 Title  \
# 0   강원/강릉시 기준 2명 (최대 2명) ₩270,000 ~ ₩290,000 - 스테이폴리오
# 1                                            라이프이즈로맨스
# 2                                       명주하녹 - 스테이폴리오
# 3                                   MAGAZINE - 스테이폴리오
# 4   내가 가려고 모아두는 감성 숙소 LIST -) 강릉편 3 (영진스테이, 오붓한강릉,...
# 5                                     전통홍염공방 - 서울한옥포털
# 6                                     색실누비공방 - 서울한옥포털
# 7   (보도자료) 북촌 공공한옥으로 단오 나들이…‘여름을 준비하는 날, 단오’행사 개최....
# 8             가공식품 &gt; 농특산물안내 &gt; 공주시 농업기술센터 - 공주시청
# 9   https://www.gongju.go.kr/cmm/fms/FileDown.do?a...
# 10  언론보도 - [한국의 명가 명택 &lt;12&gt;｜강릉 선교장 (船橋莊)] (동아일보)
# 11   입선 - Korean Fine Arts Association :: 사단법인 한국미술협회
# 12  https://www.gongju.go.kr/cmm/fms/FileDown.do?a...
# 13                   대구광역시 남구_먹거리골목 업소현황_20210802.xls
# 14             농어촌민박 현황 세부내역(12월말 기준)-제주시.xlsx - 제주시청
# 15     4. ,도내 숙박시설 현황 세부내역(11월 리스트) 도.xlsx - 제주특별자치도청
# 16                                      개역성경 - 다음 블로그
# 17  SEOUL NATIONAL UNIVERSITY U.S. ALUMNI NEWS 서울대...
# 18                    haebuk1837.xlsx - 성균관대학교 홈페이지빌더
# 19  5-1.숙박시설(농어촌민박) 현황 세부내역(21.2월말 기준).xlsx - 제주특별...
# 20                              농어촌 민박 현황.xlsx - 제주시청
# 21     도내숙박시설 총괄 현황(리스트포함)_2018년 11월말.xlsx - 제주특별자치도청
# 22                                    남경중앙교회 - 다음 블로그
# 23           5-1. 숙박시설(농어촌민박) 현황 세부내역(21. 1월 기준).xlsx
# 24       숙박시설(농어촌민박) 현황 세부내역(1월말기준)-농어촌민박.xlsx - 제주시청
# 25       2. 도내 숙박시설 현황 세부내역(리스트)-6.30.xlsx - 제주특별자치도청
# 26                         길과 진리 생명 (요 14:6) - 다음 블로그
# 27                 제주시 농어촌민박 현황(2.18. 기준).xlsx - 제주시청
# 28  숙박시설(농어촌민박) 현황 세부내역(2020년 1월말 기준)-관광정책과-.xlsx ...
# 29    5.1.숙박시설(농어촌민박) 현황 세부내역(4월말 기준).xlsx - 제주특별자치도청
# 30          제주시 농어촌민박 등록현황(2020. 10월말 기준).xlsx - 제주시청
# 31                숙박시설(농어촌민박)현황 세부내역(9월말).xlsx - 제주시청
# 32         5. 도내 숙박시설현황 세부내역(10월말 기준).xlsx - 제주특별자치도청
# 33           5. 숙박시설세부리스트_도수합(11월 기준).xlsx - 제주특별자치도청
# 34                                     stock - 다음 블로그
# 35         5. 도내 숙박시설세부리스트(타과 포함) 도수합.xlsx - 제주특별자치도청
# 36        유니 이름 순위 - 한국인 아기 이름 작명 인기순위 도우미 서비스 - 아기이름
# 37           농어촌민박 현황 (2020년 11월말 기준-제주시).xlsx - 제주시청
# 38                        [스크랩] 구약의 성경 핵심 정리 - 다음 블로그
# 39         숙박시설(농어촌민박)현황 세부내역(9월말) 총괄.xlsx - 제주특별자치도청
# 40                    3. 숙박시설세부리스트(7월)_ 타과 포함 수합.xlsx
# 41  2 제주오리엔탈호텔 제주시 탑동로 47(삼도이동) 321 ***-***-**** -...
# 42          5. 숙박시설 현황 세부내역( 9월)- 도수합.xlsx - 제주특별자치도청
# 43               4. 숙박시설세부리스트(3월)-도수합.xlsx - 제주특별자치도청
# 44                                       바래홈 - 다음 블로그
# 45               5. 숙박시설세부리스트(6월) 도수합.xlsx - 제주특별자치도청
# 46                 5-1. 숙박시설(농어촌민박)현황 세부내역(12월말).xlsx
# 47                     5. 숙박시설 현황 세부내역( 9월)- 도수합.xlsx
# 48   5-1. 숙박시설(농어촌민박) 현황 세부내역(3월말 기준).xlsx - 제주특별자치도청
# 49         숙박시설(농어촌민박)현황 세부내역(9월말) 총괄.xlsx - 제주특별자치도청
# 50  5.1.숙박시설(농어촌민박) 현황 세부내역(4월말 기준).xlsx - 제주도청 영문...
# 51   6. 다른과 숙박업 리스트 현황(19 1월말 기준).xlsx - 제주도청 영문 홈페이지
# 52        6. 숙박시설(농어촌민박)현황 세부내역(10월말).xlsx - 제주특별자치도청
# 53     숙박시설(농어촌민박)현황 세부내역(9월말) 총괄.xlsx - 제주도청 영문 홈페이지
# 54         숙박시설(농어촌민박)현황 세부내역(9월말) 총괄.xlsx - 제주특별자치도청
# 55     3. 숙박시설세부리스트(7월)_ 타과 포함 수합.xlsx - 제주도청 영문 홈페이지
#
#                                                  Link  \
# 0   https://www.stayfolio.com/findstay/myeongju-hanok
# 1                         http://lifeisromance.co.kr/
# 2   https://www.stayfolio.com/findstay/myeongju-ha...
# 3   https://www.stayfolio.com/journal/magazines/ha...
# 4     https://blog.naver.com/smaterpiece/222337596317
# 5   https://hanok.seoul.go.kr/cmm/fms/FileDown.do?...
# 6   https://hanok.seoul.go.kr/cmm/fms/FileDown.do?...
# 7   https://hanok.seoul.go.kr/cmm/fms/FileDown.do?...
# 8      https://hanok.gongju.go.kr/farming/sub05_04.do
# 9   https://www.gongju.go.kr/cmm/fms/FileDown.do?a...
# 10                       http://hanok.org/press/13823
# 11  http://www.kfaa.or.kr/_newbie/convention/new_c...
# 12  https://www.gongju.go.kr/cmm/fms/FileDown.do?a...
# 13  https://nam.daegu.kr/icms/cmm/fms/FileDown.do?...
# 14  https://www.jejusi.go.kr/boardFileDown.ac?file...
# 15  https://www.jeju.go.kr/group/part15/refer.htm?...
# 16                  https://blog.daum.net/indaep/1963
# 17  https://snuaa.org/main/wp-content/uploads/2019...
# 18  https://skb.skku.edu/_res/ddmh/etc/haebuk1837....
# 19  https://www.jeju.go.kr/news/news/data.htm?act=...
# 20  https://www.jejusi.go.kr/opendata/table/excelD...
# 21  https://www.jeju.go.kr/group/part28/refer.htm?...
# 22          https://blog.daum.net/zhulongchun/7675545
# 23  https://jeju.go.kr/news/news/data.htm?act=down...
# 24  https://www.jejusi.go.kr/boardFileDown.ac?file...
# 25  https://www.jeju.go.kr/group/part13/refer.htm?...
# 26           https://blog.daum.net/immanuelgrace/2037
# 27  https://www.jejusi.go.kr/boardFileDown.ac?file...
# 28  https://www.jeju.go.kr/news/news/data.htm?act=...
# 29  http://www.jeju.go.kr/news/news/data.htm?act=d...
# 30  https://www.jejusi.go.kr/boardFileDown.ac?file...
# 31  https://www.jejusi.go.kr/boardFileDown.ac?file...
# 32  https://www.jeju.go.kr/news/news/data.htm?act=...
# 33  https://www.jeju.go.kr/news/news/data.htm?act=...
# 34      https://blog.daum.net/myhome42567087/15656709
# 35  https://www.jeju.go.kr/news/news/data.htm?act=...
# 36   https://baby-name.kr/ranking/%EC%9C%A0%EB%8B%88/
# 37  https://www.jejusi.go.kr/boardFileDown.ac?file...
# 38             https://blog.daum.net/godson1009/16003
# 39  http://news.jeju.go.kr/news/news/data.htm?act=...
# 40  https://jeju.go.kr/group/part28/refer.htm?act=...
# 41  http://bohun.jeju.go.kr/group/part28/refer.htm...
# 42  https://www.jeju.go.kr/group/part28/refer.htm?...
# 43  https://www.jeju.go.kr/group/part15/refer.htm?...
# 44               https://blog.daum.net/kcsmt1370/1139
# 45  https://www.jeju.go.kr/group/part15/refer.htm?...
# 46  http://jeju.go.kr/news/news/data.htm?act=downl...
# 47  https://jeju.go.kr/news/news/data.htm?act=down...
# 48  http://bohun.jeju.go.kr/group/part28/refer.htm...
# 49  http://bohun.jeju.go.kr/group/part28/refer.htm...
# 50  http://english.jeju.go.kr/news/news/data.htm?a...
# 51  http://english.jeju.go.kr/group/part28/refer.h...
# 52  http://bohun.jeju.go.kr/group/part28/refer.htm...
# 53  http://english.jeju.go.kr/group/part28/refer.h...
# 54  http://bohun.jeju.go.kr/news/news/data.htm?act...
# 55  http://english.jeju.go.kr/group/part28/refer.h...
#
#                                           Description
# 0   예약 변경 및 기타 문의사항은 명주하녹(0504-0904-2476)으로 연락 주시기...
# 1                              당신의 낭만을 그립니다, 라이프이즈로맨스
# 2   예약 변경 및 기타 문의사항은 명주하녹(0504-0904-2476)으로 연락 주시기...
# 3   사람의 시선은 물리적으로 안이 아닌 밖을 향해 있다. 자신을 보기보다 타인과 바깥을...
# 4   명주하녹 바다와 가까운 아늑한 땅 '명주' 사계절 여름의 푸르름을 간직한 공간으로 ...
# 5   약 15평 정도 되는 자그마한 한옥에는 구석구석 염색재료와 명주실... 최초의 명주...
# 6   또 옛날 에는 무명을 사용했는데, 저는 명주나 옻칠한 천도 사용하며 소재 개발을 하...
# 7   ‣10:00~18:00, 북촌한옥청 전시실, 무료 ○ 아트마켓: 공공한옥 장인들이 ...
# 8   한국의 명주로서 색과 향이 독특하고 담백한 맛이 일품입니다. 계룡산 인근의 청정지역...
# 9   - 1 - 【 】 1266 ·······························...
# 10  언론보도 홈페이지 문화원소개 언론보도 2009.07.15 10:51[한국의 명가 명...
# 11  한국화 0212 한석희 불국사 범영루 한국화 0214 김명희 바위의 변주곡 한국화 ...
# 12  도로명주... 도로명주... 도로명주소 폐지 고시 ··················...
# 13  대구광역시 남구_먹거리골목 업소현황_20210802 위도 경도 골목 업종명 업소명 ...
# 14  농어촌민박(등록용) 농어촌민박 현황 ('20.12.31.기준) 연번 행정시별 상호명...
# 15  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 연락처 비고 1 글래드호텔...
# 16  개역성경 댓글 0 교회생활/개역성경 2017. 11. 17. 창1:1 태초에 하나님...
# 17  300호 | 2019년 4월 호 서울대 미주동창회보 1 동창회보 창간 발행을 회고하...
# 18  Sheet1 原本 年度 面名 면명 順番 里順 里名 리명 統 統首 통수 戶 主戶 주호...
# 19  농어촌민박 현황 2021년 농어촌민박 현황 구 분 2021.1.31.기준 2021....
# 20  농어촌민박현황 읍면동 업소명 소재지 한림읍 기영 민박 제주시 한림읍 한림로 345 ...
# 21  관광호텔 관광호텔업 현황 연번 행정시 상호명 소재지 객실수 전화번호 비고 1 제주시...
# 22  구약의 성경 핵심 정리 창세기(50)--------------------------...
# 23  농어촌민박 현황 2021년 농어촌민박 현황 구 분 2021.1.31.기준 계 230...
# 24  농어촌민박(리스트) 농어촌민박 현황('19.01.31.기준) 연번 행정시별 상호명 ...
# 25  일반숙박업 일반숙박업 현황 연번 행정시별(담당전화) 상호명 소재지 객실수 비고 1 ...
# 26  구약의 성경 핵심 정리 창세기(50)--------------------------...
# 27  Sheet1 농어촌민박 운영 현황(2019년 2월말 기준)-제주시 순번 읍면동 명 ...
# 28  농어촌민박 농어촌민박 현황 연번 행정시별 상호명 소재지 객실수 비고 1 한림읍(06...
# 29  농어촌민박 현황 2021년 농어촌민박 현황 구 분 2021.1.31.기준 2021....
# 30  농어촌민박(등록용) 농어촌민박 현황 ('20.10.31.기준) 연번 행정시별 상호명...
# 31  제주시(등록용) 농어촌민박 현황('20.09.30.기준) 연번 행정시별 상호명 소재...
# 32  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 연락처 비고 1 글래드호텔...
# 33  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 연락처 비고 1 글래드호텔...
# 34   구약의 성경 핵심 정리 창세기(50)-------------------------...
# 35  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 연락처 비고 1 글래드호텔...
# 36  순위를 알고 싶은 이름을 입력해보세요 이름 짓기 편하게 많은 이름 자료들을 보기 쉽...
# 37  농어촌민박(등록용) 농어촌민박 현황 ('20.11.30.기준) 연번 행정시별 상호명...
# 38  [스크랩] 구약의 성경 핵심 정리 댓글 0 구약신학!! 구약개론!! 2015. 4....
# 39  제주시(등록용) 농어촌민박 현황('20.09.30.기준) 연번 행정시별 상호명 소재...
# 40  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 연락처 비고 1 글래드호텔...
# 41  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 연락처 비고 1 글래드호텔...
# 42  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 비고 1 글래드호텔앤리조트...
# 43  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 연락처 비고 1 글래드호텔...
# 44  구약의 성경 핵심 정리 창세기(50)--------------------------...
# 45  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 연락처 비고 1 글래드호텔...
# 46  농어촌민박 현황 2020년 농어촌민박 현황 구 분 2020.1.31.기준 2020....
# 47  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 비고 1 글래드호텔앤리조트...
# 48  농어촌민박 현황 2021년 농어촌민박 현황 구 분 2021.1.31.기준 2021....
# 49  제주시(등록용) 농어촌민박 현황('20.09.30.기준) 연번 행정시별 상호명 소재...
# 50  농어촌민박 현황 2021년 농어촌민박 현황 구 분 2021.1.31.기준 2021....
# 51  농어촌민박 농어촌민박 현황('19.1.31.기준) 연번 행정시별 상호명 소재지 객실...
# 52  농어촌민박 현황 2020년 농어촌민박 현황 구 분 2020.1.31.기준 2020....
# 53  제주시(등록용) 농어촌민박 현황('20.09.30.기준) 연번 행정시별 상호명 소재...
# 54  제주시(등록용) 농어촌민박 현황('20.09.30.기준) 연번 행정시별 상호명 소재...
# 55  관광호텔업 관광호텔업 등록현황 순번 상호명 소재지 객실수 연락처 비고 1 글래드호텔...

# %%
web_df['Description'][4]
# Out:
# '홈 외국도서 컴퓨터 컴퓨터 인터넷/웹 개발 프로그래밍 운영체제(OS)... 오피스 컴퓨터자격서 하드웨어 데이터베이스 바로가기 전체상품 | 새로나온도서... '

# %% [markdown]
# ---

# %% [markdown]
# ### 네이버 블로그 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

# naver application clientID,secret
client_id = "6E6mBjvxbdEgVk6Prqgd"
client_secret = "0ZjWnYiBjr"


# quote가 인코딩을 변경(UTF8로 url에 넘겨주기 위해서)
# 내가 입력한 값을 기준으로 parse
query = urllib.parse.quote(input("검색 질의: "))
idx = 0 # 요청 개수
display = 100 # 100개 단위로 가져온다
start = 1
end = 1000

# 데이터 프레임 생성
blog_df = pd.DataFrame(columns=("Title", "Link", "Description","Blogger Name","Blogger Link","Post Date"))

for start_index in range(start, end, display):
    # json 결과
    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    # request 요청에 대한 결과를 response에 저장
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '',items[item_index]['description'])
            blogger_name = items[item_index]['bloggername']
            blogger_link = items[item_index]['bloggerlink']
            post_date = items[item_index]['postdate']
            blog_df.loc[idx] = [title, link, description, blogger_name, blogger_link, post_date]
            idx += 1
            
    else:
        print("Error Code:" + rescode)

blog_df
# Out:
# 검색 질의:  명주 하녹
#                                         Title  \
# 0                          고즈넉한 사색의 공간 : 명주하녹
# 1                                  [#강릉] 명주하녹
# 2                                     #172_8월
# 3                        밀린 이야기들@@@@(8월-9월중순)
# 4                                 01. 강릉 명주하녹
# ..                                        ...
# 165          나만 알고 싶었던 강릉 감성 숙소, 한옥 스테이 #명주하녹
# 166    [국내여행] 강릉 명주하녹 : 가만히 있어도 마음이 편해지는 곳 :D
# 167                          5월 2박3일 강릉여행 2일차
# 168  [20210810] 강릉 숙소 / 강릉 감성숙소 / 강릉 에어비앤비 추천
# 169        월간 남편 생일 2탄: 강원도 강릉여행 | 독채스테이 명주하녹
#
#                                                   Link  \
# 0    https://blog.naver.com/stayfolio?Redirect=Log&...
# 1    https://blog.naver.com/kjw930603?Redirect=Log&...
# 2    https://blog.naver.com/rkawlrdlgpfl?Redirect=L...
# 3    https://blog.naver.com/m_space00?Redirect=Log&...
# 4    https://blog.naver.com/wjddkrla92?Redirect=Log...
# ..                                                 ...
# 165  https://blog.naver.com/jeong_9195?Redirect=Log...
# 166  https://blog.naver.com/magical7?Redirect=Log&l...
# 167  https://blog.naver.com/kkangda9090?Redirect=Lo...
# 168  https://blog.naver.com/yoona626?Redirect=Log&l...
# 169  https://blog.naver.com/chichi0220?Redirect=Log...
#
#                                            Description  \
# 0    명주하녹을 마주할 때도 마찬가지이다. 강릉 명주동의 오래된 주택가 골목길을 쭉 따라...
# 1    강릉 명주하녹 5월에 예약하고 8월에 방문한 명주하녹 요샌 가고자 하는 곳에 가려면...
# 2    요즘은 하늘이 계속 꾸리꾸리하다 조금 남은 꽃들 이거라도 말려보자! 이거 위아래 그...
# 3    (부럽) 그리고 학교 다닐 때부터 가보고 싶었던 캠핑 카페 &lt;하녹테라스&gt;...
# 4    예약했다가, 명주하녹을 보는 순간 바로 취소 독채 숙소에 공간 자체가 다 깔끔하고 ...
# ..                                                 ...
# 165  일단 #강릉감성숙소 를 찾으면서 #명주하녹 을 보는 순간 다른 곳들은 눈에 들어오지...
# 166  정말 그때 예약했던게 운이 좋았던거 같아 :) 강릉 명주동 명주하녹 강릉역에서 그리...
# 167  2박3일 국내여행지 추천 5월 2박3일 강릉여행 2일차 일정 유진면옥 -&gt; 강...
# 168  명주하녹  인스타그램 주소 https://www.instagram.com/myeon...
# 169  월간 남편 생일 2탄 강원도 강릉여행 독채 스테이 명주하녹 담백하고 우아한 숙소 조...
#
#                  Blogger Name                         Blogger Link Post Date
# 0    머무는 것 자체로 여행이 되는 숙소 큐레이션     https://blog.naver.com/stayfolio  20210429
# 1                    Hi. Blog     https://blog.naver.com/kjw930603  20210830
# 2                      eNoUgH  https://blog.naver.com/rkawlrdlgpfl  20210827
# 3                  Wanderlust     https://blog.naver.com/m_space00  20170912
# 4                     이것 저것 :    https://blog.naver.com/wjddkrla92  20210828
# ..                        ...                                  ...       ...
# 165                  3th Blog    https://blog.naver.com/jeong_9195  20210502
# 166                 기억 저장소 :D      https://blog.naver.com/magical7  20210622
# 167            다혜 하고 싶은 거 다~해   https://blog.naver.com/kkangda9090  20210518
# 168                 每天 : 메이티엔      https://blog.naver.com/yoona626  20210810
# 169                   D양의 사생활    https://blog.naver.com/chichi0220  20210619
#
# [170 rows x 6 columns]

# %%
blog_df['Link'][3]
# Out:
# 'https://blog.naver.com/indo3450?Redirect=Log&logNo=222488439750'

# %% [markdown]
# ---

# %% [markdown]
# ### 네이버 장소 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import numpy as np
import json
import re


# naver application clientID,secret
client_id = "6E6mBjvxbdEgVk6Prqgd"
client_secret = "0ZjWnYiBjr"


# quote가 인코딩을 변경(UTF8로 url에 넘겨주기 위해서)
# 내가 입력한 값을 기준으로 parse
query = urllib.parse.quote(input("검색 질의: "))
idx = 0 # 요청 개수
display = 100 # 100개 단위로 가져온다
start = 1
end = 1000

# 데이터 프레임 생성
location_df = pd.DataFrame(columns=("Title", "Link", "Category","Description","Telephone","Address","RoadAddress","Mapx","Mapy"))

for start_index in range(start, end, display):
    # json 결과
    url = "https://openapi.naver.com/v1/search/local?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    # request 요청에 대한 결과를 response에 저장
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            caterory = items[item_index]['category']
            description = re.sub(remove_tag, '',items[item_index]['description'])
            telephone = items[item_index]['telephone']
            address = items[item_index]['address']
            roadAddress = items[item_index]['roadAddress']
            mapx = items[item_index]['mapx']
            mapy = items[item_index]['mapy']
            
            res =  [title, link, caterory, description, telephone, address, roadAddress, mapx, mapy]
            def checkNull(x):
                if not x:
                    x = np.nan
                return x
            res = list(map(checkNull,res))
            
            location_df.loc[idx] = res
            idx += 1
    else:
        print("Error Code:" + rescode)

location_df
# Out:
# 검색 질의:  명주 하녹
#   Title                                       Link Category Description  \
# 0  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
# 1  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
# 2  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
# 3  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
# 4  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
# 5  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
# 6  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
# 7  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
# 8  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
# 9  명주하녹  https://www.instagram.com/myeongju_hanok/  숙박>전통숙소         NaN
#
#   Telephone             Address              RoadAddress    Mapx    Mapy
# 0       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445
# 1       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445
# 2       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445
# 3       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445
# 4       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445
# 5       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445
# 6       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445
# 7       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445
# 8       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445
# 9       NaN  강원도 강릉시 명주동  50-16  강원도 강릉시 경강로2021번안길 11-4  478607  572445

# %% [markdown]
# ---
